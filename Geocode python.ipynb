# %%
from opencage.geocoder import OpenCageGeocode
import pandas as pd

# %%
keys = [
    #"80402923a7454df6a2ab43cd13171cfb" # lalo
    # "df0e883dd29a43b4ba7a1b39cf40f12a" # esteban
    #"84b20f7974a24b60b4acc1f0416d8795", # eduardo
    #"16f1e15a620d483f97b60a0a5baa0e1d", # marquez
    #"b53d1aa5d3d34373ac023d90e3e1b891" # fuentes
    # "8bb08353bb5a4c3b82eae9de3d44b33e" # mia
    #"77781c9bcca943b78903c352e699335d" #nose238
     "67a01badffdf43719188d8f74e062f11" #J
    # "1ad62d607a85481bb063bbdbac473600" # JS
]

# %%
df = pd.read_excel("coordenadas20210914.xlsx")

# %%
df
# Out:
#         latitud   longitud
# 0     19.832604 -99.203858
# 1     19.346602 -98.958728
# 2     19.258209 -99.595889
# 3     19.395294 -98.947686
# 4     19.330289 -99.643009
# ...         ...        ...
# 7943  19.039826 -98.183605
# 7944  18.970125 -98.263690
# 7945  19.296235 -99.185633
# 7946  19.363067 -99.638644
# 7947  19.053089 -98.193649
#
# [7948 rows x 2 columns]

# %%
states = []
start = 6616
end = 2500 + 6616
for key in keys:
    geocoder = OpenCageGeocode(key)
    for i in range(start, end+1):
        if i > len(df):
            break
        result = geocoder.reverse_geocode(df.iloc(0)[i]["latitud"], df.iloc(0)[i]["longitud"])
        try:
            r = result[0]["components"]["state"]
        except:
            r = ""
        states.append(r)
        print("element added: " + str(i) )
    start = end + 1
    end = start + end
    if start > len(df):
        break
# Out:
# element added: 6616
# element added: 6617
# element added: 6618
# element added: 6619
# element added: 6620
# element added: 6621
# element added: 6622
# element added: 6623
# element added: 6624
# element added: 6625
# element added: 6626
# element added: 6627
# element added: 6628
# element added: 6629
# element added: 6630
# element added: 6631
# element added: 6632
# element added: 6633
# element added: 6634
# element added: 6635
# element added: 6636
# element added: 6637
# element added: 6638
# element added: 6639
# element added: 6640
# element added: 6641
# element added: 6642
# element added: 6643
# element added: 6644
# element added: 6645
# element added: 6646
# element added: 6647
# element added: 6648
# element added: 6649
# element added: 6650
# element added: 6651
# element added: 6652
# element added: 6653
# element added: 6654
# element added: 6655
# element added: 6656
# element added: 6657
# element added: 6658
# element added: 6659
# element added: 6660
# ...

# %%
geocoder = OpenCageGeocode(keys[0])
result = geocoder.reverse_geocode(df["latitud"], df["longitud"])  
# result[0]["components"]["state"]
# Out:
# ---------------------------------------------------------------------------
# InvalidOperation                          Traceback (most recent call last)
# <ipython-input-7-a10b503fbaa9> in <module>
#       1 geocoder = OpenCageGeocode(keys[0])
# ----> 2 result = geocoder.reverse_geocode(df["latitud"], df["longitud"])
#       3 # result[0]["components"]["state"]
#
# ~\Anaconda3\lib\site-packages\opencage\geocoder.py in reverse_geocode(self, lat, lng, **kwargs)
#     210         :raises UnknownError: if something goes wrong with the OpenCage API
#     211         """
# --> 212         return self.geocode(_query_for_reverse_geocoding(lat, lng), **kwargs)
#     213
#     214     async def reverse_geocode_async(self, lat, lng, **kwargs):
#
# ~\Anaconda3\lib\site-packages\opencage\geocoder.py in _query_for_reverse_geocoding(lat, lng)
#     309     # decimal places as the user already specified and (b) to ensure we don't
#     310     # get e-5 stuff
# ...

# %%
geocoder = OpenCageGeocode("84b20f7974a24b60b4acc1f0416d8795")
result = geocoder.reverse_geocode(18.9680155, -98.2400712)  
result[0]["components"]["state"]
# Out:
# ---------------------------------------------------------------------------
# ForbiddenError                            Traceback (most recent call last)
# <ipython-input-66-401ea6679626> in <module>
#       1 geocoder = OpenCageGeocode("84b20f7974a24b60b4acc1f0416d8795")
# ----> 2 result = geocoder.reverse_geocode(18.9680155, -98.2400712)
#       3 result[0]["components"]["state"]
#
# ~\Anaconda3\lib\site-packages\opencage\geocoder.py in reverse_geocode(self, lat, lng, **kwargs)
#     210         :raises UnknownError: if something goes wrong with the OpenCage API
#     211         """
# --> 212         return self.geocode(_query_for_reverse_geocoding(lat, lng), **kwargs)
#     213
#     214     async def reverse_geocode_async(self, lat, lng, **kwargs):
#
# ~\Anaconda3\lib\site-packages\opencage\geocoder.py in geocode(self, query, **kwargs)
#     166
#     167         request = self._parse_request(query, kwargs)
# --> 168         response = self._opencage_request(request)
#     169
# ...

# %%
result
# Out:
# [{'annotations': {'DMS': {'lat': "18° 58' 6.70656'' N",
#     'lng': "98° 14' 23.42004'' W"},
#    'MGRS': '14QNF8002397517',
#    'Maidenhead': 'EK08vx12fk',
#    'Mercator': {'x': -10936008.842, 'y': 2137349.036},
#    'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?node=7033852954#map=16/18.96853/-98.23984',
#     'note_url': 'https://www.openstreetmap.org/note/new#map=16/18.96853/-98.23984&layers=N',
#     'url': 'https://www.openstreetmap.org/?mlat=18.96853&mlon=-98.23984#map=16/18.96853/-98.23984'},
#    'UN_M49': {'regions': {'AMERICAS': '019',
#      'CENTRAL_AMERICA': '013',
#      'LATIN_AMERICA': '419',
#      'MX': '484',
#      'WORLD': '001'},
#     'statistical_groupings': ['LEDC']},
#    'callingcode': 52,
#    'currency': {'alternate_symbols': ['MEX$'],
#     'decimal_mark': '.',
#     'disambiguate_symbol': 'MEX$',
#     'html_entity': '$',
#     'iso_code': 'MXN',
#     'iso_numeric': '484',
#     'name': 'Mexican Peso',
#     'smallest_denomination': 5,
# ...

# %%
coordinates = [
    (18.9680155, -98.2400712),
    (19.3093954, -99.1871668),
    (18.9878675, -98.2166232),
    (20.5853001, -100.3917501),
    (18.8324819, -99.1949144)
]

for site in coordinates:
    result = geocoder.reverse_geocode(site)
    print(result[0]["components"]["state"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-e67d831d1932> in <module>
#       8
#       9 for site in coordinates:
# ---> 10     result = geocoder.reverse_geocode(site)
#      11     print(result[0]["components"]["state"])
#
# TypeError: reverse_geocode() missing 1 required positional argument: 'lng'

# %%
coordinates = [
    [18.9680155, -98.2400712],
    #[19.3093954, -99.1871668],
    [18.9878675, -98.2166232],
    [20.5853001, -100.3917501],
    [18.8324819, -99.1949144]
]

for site in coordinates:
    result = geocoder.reverse_geocode(site[0], site[1])
    print(result[0]["components"]["state"])
# Out:
# Puebla
# Puebla
# Querétaro
# Morelos

# %%
result = geocoder.reverse_geocode(19.3093954, -99.1871668)  
result[0]["components"]["postcode"]
# Out:
# '04530'

# %%
df.iloc(0)[0]["latitud"]
# Out:
# 19.8326044

# %%
df
# Out:
#         latitud   longitud
# 0     19.832604 -99.203858
# 1     19.346602 -98.958728
# 2     19.258209 -99.595889
# 3     19.395294 -98.947686
# 4     19.330289 -99.643009
# ...         ...        ...
# 7943  19.039826 -98.183605
# 7944  18.970125 -98.263690
# 7945  19.296235 -99.185633
# 7946  19.363067 -99.638644
# 7947  19.053089 -98.193649
#
# [7948 rows x 2 columns]

# %%
len(df)
# Out:
# 7948

# %%
result = geocoder.reverse_geocode(df.iloc(0)[0]["latitud"], df.iloc(0)[0]["longitud"])

# %%
result
# Out:
# [{'annotations': {'DMS': {'lat': "19° 49' 56.99748'' N",
#     'lng': "99° 12' 13.92516'' W"},
#    'MGRS': '14QMG7865192958',
#    'Maidenhead': 'EK09jt59mt',
#    'Mercator': {'x': -11043324.079, 'y': 2238708.858},
#    'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?way=335529059#map=17/19.83250/-99.20387',
#     'note_url': 'https://www.openstreetmap.org/note/new#map=17/19.83250/-99.20387&layers=N',
#     'url': 'https://www.openstreetmap.org/?mlat=19.83250&mlon=-99.20387#map=17/19.83250/-99.20387'},
#    'UN_M49': {'regions': {'AMERICAS': '019',
#      'CENTRAL_AMERICA': '013',
#      'LATIN_AMERICA': '419',
#      'MX': '484',
#      'WORLD': '001'},
#     'statistical_groupings': ['LEDC']},
#    'callingcode': 52,
#    'currency': {'alternate_symbols': ['MEX$'],
#     'decimal_mark': '.',
#     'disambiguate_symbol': 'MEX$',
#     'html_entity': '$',
#     'iso_code': 'MXN',
#     'iso_numeric': '484',
#     'name': 'Mexican Peso',
#     'smallest_denomination': 5,
# ...

# %%
cont = 0
for state in allStates:
    if state == "":
        cont = cont + 1

# %%
cont
# Out:
# 466

# %%
len(states)
# Out:
# 3761

# %%
cont/len(allStates)
# Out:
# 0.05863110216406643

# %%
states3760 = states

# %%
states3760
# Out:
# ['State of Mexico',
#  'State of Mexico',
#  'State of Mexico',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  '',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  '',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  '',
#  'State of Mexico',
#  'Puebla',
#  'Morelos',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
# ...

# %%
states4151
# Out:
# ['Puebla',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  '',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  '',
#  '',
#  'State of Mexico',
#  'State of Mexico',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Morelos',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'State of Mexico',
# ...

# %%
states4839
# Out:
# ['Puebla',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  '',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'Morelos',
#  'State of Mexico',
#  'Puebla',
#  '',
#  'Puebla',
#  'Puebla',
#  '',
#  'State of Mexico',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'State of Mexico',
#  'State of Mexico',
#  '',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  '',
#  'State of Mexico',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
# ...

# %%
states6615
# Out:
# ['Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  '',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  '',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  '',
#  'Puebla',
#  'Morelos',
#  'State of Mexico',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  '',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  '',
#  'Puebla',
#  'State of Mexico',
# ...

# %%
states7947
# Out:
# ['State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  '',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  '',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'Morelos',
#  'State of Mexico',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
# ...

# %%
allStates = states3760 + states4151+  states4839 + states6615 + states7947

# %%
len(allStates)
# Out:
# 7948

# %%
se = pd.Series(allStates)
df['estados'] = se.values

# %%
df
# Out:
#         latitud   longitud          estados
# 0     19.832604 -99.203858  State of Mexico
# 1     19.346602 -98.958728  State of Mexico
# 2     19.258209 -99.595889  State of Mexico
# 3     19.395294 -98.947686  State of Mexico
# 4     19.330289 -99.643009  State of Mexico
# ...         ...        ...              ...
# 7943  19.039826 -98.183605           Puebla
# 7944  18.970125 -98.263690           Puebla
# 7945  19.296235 -99.185633
# 7946  19.363067 -99.638644  State of Mexico
# 7947  19.053089 -98.193649           Puebla
#
# [7948 rows x 3 columns]

# %%
df.to_excel("conEstados.xlsx")

# %%
states
# Out:
# ['State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  '',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  '',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'Morelos',
#  'State of Mexico',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
#  'State of Mexico',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'Puebla',
#  'State of Mexico',
#  'State of Mexico',
# ...
